# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Владимир, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Описание проекта

# %% [markdown]
# **Заголовок:** Исследование сервиса аренды самокатов GoFast.
# **Описание проекта:** Средства индивидуальной мобильности сегодня являются неотъемлемой частью повседневной жизни городского жителя. Популярность сервисов проката самокатов постоянно увеличивается, конкуренция также растет. На основании имеющихся данных проведем анализ пользователей сервиса аренды самокатов и проверим некоторые гипотезы. \
# **Цель исследования** Выявить основные категории пользователей, города с наибольшей популярностью сервиса. Проверим приносят ли пользователи с подпиской дополнительный доход компании или нет. Проверим гипотезы об оптимальном износе самокатов.
# Пользователи делятся на 2 категории: с подпиской, без подписки.
# * без подписки \
#     абонентская плата отсутствует; \
#     стоимость одной минуты поездки — 8 рублей; \
#     стоимость старта (начала поездки) — 50 рублей;
# * с подпиской Ultra \
#     абонентская плата — 199 рублей в месяц; \
#     стоимость одной минуты поездки — 6 рублей; \
#     стоимость старта — бесплатно.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝  Хорошо структурированное вступление делает проект более профессиональным, понятным и ценным для читателя и заказчика.
#
# Вот краткий пример на основе проекта: Исследовательский анализ данных.
#
# ![%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg](attachment:%D0%92%D1%81%D1%82%D1%83%D0%BF%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5.jpg)
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Исправил вступительную часть в соответствии с твоими предложениями.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %% [markdown]
# **1.1** Загрузим необходимые для работы библиотеки. Добавим переменные с названиями датасетов

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import numpy as np
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %%
try:
    data_usrs = pd.read_csv('c:/Users/vovze/practicum/scooter_rental_srvc/users_go.csv')
except:
    data_usrs = pd.read_csv('/datasets/users_go.csv')

try:
    data_rdrs = pd.read_csv('c:/Users/vovze/practicum/scooter_rental_srvc/rides_go.csv')
except:
    data_rdrs = pd.read_csv('/datasets/rides_go.csv')

try:
    data_subscr = pd.read_csv('c:/Users/vovze/practicum/scooter_rental_srvc/subscriptions_go.csv')
except:
    data_subscr = pd.read_csv('/datasets/subscriptions_go.csv')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 Здорово, что следишь за универсальностью загрузки данных и используешь `try-except` блок.
# </div>

# %% [markdown]
# **1.2** Просмотрим первые строки каждого датасета, выведем на экран количество строк и типы данных.

# %% [markdown]
# ##### Датасет с данными о пользователях

# %%
display (data_usrs.head()) 
data_usrs.info()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB

# %% [markdown]
# ##### Датасет с данными о расстоянии и продолжительности поездок пользователей.

# %%
display (data_rdrs.head()) 
data_rdrs.info()
# Out:
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 564.8+ KB

# %% [markdown]
# Количество элементов во всех столбцах одинаково, можно сделать вывод что пропусков нет, но возможны дубликаты и неверные значения.

# %% [markdown]
# ##### Датасет с данными о подписках.

# %%
display (data_subscr.head()) 
data_subscr.info()
# Out:
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# 1             ultra             6                 0               199
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   subscription_type  2 non-null      object
#  1   minute_price       2 non-null      int64
#  2   start_ride_price   2 non-null      int64
#  3   subscription_fee   2 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# Последовательно для каждого датасета, проверим наличие дубликатов.

# %%
data_usrs.duplicated().sum()
# Out:
# 31

# %% [markdown]
# Из общего количества 1565 строк, 31 дубликат можно удалить.

# %%
data_usrs.drop_duplicates(inplace=True)

# %% [markdown]
# Еще раз проверим остались ли дубликаты.

# %%
data_usrs.head()
# Out:
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra

# %%
data_usrs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Проверим наличие дубликатов в data_rdrs

# %%
data_rdrs.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В датасете с поездками пользователей дубликаты отсутствуют.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %% [markdown]
# **2.1** Приведём столбец date к типу даты pandas.

# %%
data_rdrs['date'] = pd.to_datetime(data_rdrs['date'], format = '%Y-%m-%d')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %%
data_rdrs['date'].head(10)
# Out:
# 0   2021-01-01
# 1   2021-01-18
# 2   2021-04-20
# 3   2021-08-11
# 4   2021-08-28
# 5   2021-10-09
# 6   2021-10-19
# 7   2021-11-06
# 8   2021-11-14
# 9   2021-11-22
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# Проверим за какой период у нас есть данные и нет ли ошибок в данных о годе и месяце.

# %%
display (data_rdrs['date'].dt.year.nunique())
display (data_rdrs['date'].dt.month.nunique())
# Out:
# 1
# 12

# %% [markdown]
# Присутствуют данные за 2021 год за 12 месяцев.

# %% [markdown]
# Округлим значения в столбце "duration" в большую сторону.

# %%
data_rdrs['duration'] = np.ceil(data_rdrs['duration'])

# %%
data_rdrs.head()
# Out:
#    user_id     distance  duration       date
# 0        1  4409.919140      26.0 2021-01-01
# 1        1  2617.592153      16.0 2021-01-18
# 2        1   754.159807       7.0 2021-04-20
# 3        1  2694.783254      19.0 2021-08-11
# 4        1  4028.687306      27.0 2021-08-28

# %%
data_rdrs['duration'].unique()
# Out:
# array([26., 16.,  7., 19., 27., 17., 15., 24., 18., 10., 25., 12., 21.,
#        14., 13., 22., 20., 23., 28., 36., 34., 11.,  6., 31., 33.,  8.,
#        29., 39., 32., 30.,  9.,  5., 37., 35., 40., 38., 41.,  4.,  1.,
#         3.])

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Правильно, что мы проверили за какой период у нас данные. Провести такую проверку важно, чтобы данные за несколько лет не склеились при агрегации по месяцам.
# </div>

# %% [markdown]
# **2.2** Создадим новый столбец с номером месяца на основе столбца date.

# %%
data_rdrs['month_number'] = data_rdrs['date'].dt.month

# %%
data_rdrs['month_number'].head(10)
# Out:
# 0     1
# 1     1
# 2     4
# 3     8
# 4     8
# 5    10
# 6    10
# 7    11
# 8    11
# 9    11
# Name: month_number, dtype: int64

# %% [markdown]
# **2.3** Проверим пропущенные значения.

# %%
data_usrs.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64

# %%
data_rdrs.isna().sum()
# Out:
# user_id         0
# distance        0
# duration        0
# date            0
# month_number    0
# dtype: int64

# %%
data_subscr.isna().sum()
# Out:
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Пропущенных значений нет.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Отлично, мы превели первичный анализ и познакомились с данными. Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Можно сделать лучше:
#
# * Округлить расстояния в `data_rdrs['distance']` методом round()
#
# * Проверить столбец `data_rdrs['duration']` на предмет наличия аномалий.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# В моем проекте округление происходит на шаге построения сводной таблицы. Хотя я с тобой согласен и лучше этот шаг сделать на этапе предобработки данных.
# Перенес этап округления значений в столбце "distance" в предобработку данных. Использовал метод np.ceil, как рекомендуется в задании.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %% [markdown]
# **3.1** Частота встречаемости городов.

# %%
usrs_by_city = data_usrs['city'].value_counts()
display(usrs_by_city)
cities = usrs_by_city.index.tolist()
users = usrs_by_city.values.tolist()

plt.figure(figsize=(15, 6))
plt.bar(cities, users)
plt.xlabel("Города")
plt.ylabel("Пользователи")
plt.title("Распределение пользователей сервиса по городам")

plt.show()
# Out:
# Пятигорск         219
# Екатеринбург      204
# Ростов-на-Дону    198
# Краснодар         193
# Сочи              189
# Омск              183
# Тюмень            180
# Москва            168
# Name: city, dtype: int64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# У секторной диаграммы очень много недостатков. Во-первых, человеческий глаз не может нормально сравнить длину дуги окружности, поскольку секторы направлены в различные стороны. Во-вторых, человеческое зрение не приспособлено к сравнению углов в принципе…
#
# Наконец, невозможно эффективно оценить величину областей, особенно если они представлены в виде неравномерных секторов в круге. Не существует способа, который бы позволял сравнивать компоненты круглой фигуры так же быстро и точно, как части прямой линии или столбца.
#
# Прошу тебя дополнительно показать, например, на барплот.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Изменил тип диаграммы на столбчатый. Теперь распределение пользователей по городам выглядит нагляднее.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Благодарю
# </div>

# %% [markdown]
# Наиболее популярным сервис оказался в пятигорске, где сервисом пользуются 219 человек. На втором месте находится Екатеринбург с 204 пользователями. Третье место занимает Ростов-на-Дону. Замыкает рейтинг Москва, вероятно по причине присутствия на рынке более успешных конкурентов.

# %% [markdown]
# **3.2** Построим диаграмму распределения пользователей по типу подписки.

# %%
subscr = data_usrs['subscription_type'].value_counts()
data_usrs['subscription_type'].value_counts().plot(kind = 'pie', y = subscr, autopct = '%1.0f%%', figsize=(7,7), 
    title = 'Распределение пользователей сервиса по типу подписки');
display (subscr)
# Out:
# free     835
# ultra    699
# Name: subscription_type, dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Супер, именно доля заведений корректно дает ответ на поставленный вопрос.
# </div>

# %% [markdown]
# Больше половины пользователей (54%) предпочитают пользоваться самокатами без оформления подписки.

# %% [markdown]
# **3.3** Построим диаграмму распределения пользователей по возрасту.

# %%
data_usrs.age.plot(kind='hist', y='age',title='Распределение пользователей сервиса по возрасту', xlabel=('Возраст'), ylabel=('Количество пользователей'), range = (0,60), bins = 20, figsize=(7,5), grid=True)
# Out:
# <AxesSubplot:title={'center':'Распределение пользователей сервиса по возрасту'}, ylabel='Frequency'>

# %% [markdown]
# Наибольшей популярностью сервис пользуется у 25 летних пользователей. Есть небольная доля пользователей моложе 15 лет, а есть совсем малая часть пользователей старше 40. Распределение близко к нормальному.

# %% [markdown]
# 3.4 Построим график расстояния, которое пользователь преодолел за одну поездку.

# %%
display (data_rdrs['distance'].describe())
st.iqr(data_rdrs['distance'])
# Out:
# count    18068.000000
# mean      3070.659976
# std       1116.831209
# min          0.855683
# 25%       2543.226360
# 50%       3133.609994
# 75%       3776.222735
# max       7211.007745
# Name: distance, dtype: float64
# 1232.9963753558854

# %% [markdown]
# Минимальная дистанция поездки составила 0.8 м, а максимальная 7211м. Медианная дистанция 3071 м. Выведем топ-10 коротких и длинных поездок.

# %%
round(data_rdrs['distance'].sort_values(), 2).head(10)
# Out:
# 11555     0.86
# 9541      2.57
# 13690     4.33
# 8658      6.78
# 7841      7.10
# 8906     11.28
# 8324     12.23
# 13940    15.00
# 15626    15.37
# 11862    15.63
# Name: distance, dtype: float64

# %%
round(data_rdrs['distance'].sort_values(ascending=False), 2).head(10)
# Out:
# 16309    7211.01
# 16484    7066.00
# 15580    6908.49
# 17171    6760.94
# 17242    6724.93
# 10341    6671.97
# 11385    6601.20
# 12086    6538.94
# 10915    6535.39
# 11319    6503.60
# Name: distance, dtype: float64

# %%
sns.boxplot(x=data_rdrs['distance'])
plt.title('Расстояние, за одну поездку')
plt.xlabel('Расстояние, м')
# Out:
# Text(0.5, 0, 'Расстояние, м')

# %% [markdown]
# **3.5** Продолжительность поездок.

# %%
display (data_rdrs['duration'].describe())
st.iqr(data_rdrs['duration'])
# Out:
# count    18068.000000
# mean        18.303520
# std          6.094928
# min          1.000000
# 25%         14.000000
# 50%         18.000000
# 75%         22.000000
# max         41.000000
# Name: duration, dtype: float64
# 8.0

# %%
13.597563-(1.5*8.127237170546415)
# Out:
# 1.4067072441803763

# %% [markdown]
# Минимальная продолжительность поездки 0.5 минуты, а максимальная продолжительность 40 минут.

# %%
round(data_rdrs['duration'].sort_values(), 2).head(10)
# Out:
# 6860     1.0
# 16704    1.0
# 10426    1.0
# 16336    1.0
# 6531     1.0
# 9282     1.0
# 15132    1.0
# 7437     1.0
# 9622     1.0
# 15771    1.0
# Name: duration, dtype: float64

# %%
round(data_rdrs['duration'].sort_values(ascending=False), 2).head(10)
# Out:
# 4215    41.0
# 4709    40.0
# 2623    40.0
# 1998    39.0
# 6453    39.0
# 143     39.0
# 3729    38.0
# 499     37.0
# 5013    37.0
# 1894    37.0
# Name: duration, dtype: float64

# %%
sns.boxplot(x=data_rdrs['duration'])
plt.title('Продолжительность одной  поездки')
plt.xlabel('Время, мин.')
# Out:
# Text(0.5, 0, 'Время, мин.')

# %% [markdown]
# Выводы:
#
# За одну поездку пользователи преодолевают обычно чуть больше 3000м и затрачивают на это около 18 минут. Поездки меньше 700 метров очень редки. Встречаются случаи когда пользователь начал поездку и закончил ее почти сразу. Вероятно либо передумали, либо обнаружили неисправность самоката.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
#  Совет: лучше писать выводы под каждым графиком, заказчику будет удобней изучать.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавил выводы под каждой диаграммой.
#
#
# </div>

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# **4.1** Объединим данные о пользователях, поездках и подписках в один датафрейм.

# %%
merged_df = data_usrs.merge(data_rdrs)
merged_df = merged_df.merge(data_subscr)
merged_df
# Out:
#        user_id     name  age       city subscription_type     distance  \
# 0            1     Кира   22     Тюмень             ultra  4409.919140
# 1            1     Кира   22     Тюмень             ultra  2617.592153
# 2            1     Кира   22     Тюмень             ultra   754.159807
# 3            1     Кира   22     Тюмень             ultra  2694.783254
# 4            1     Кира   22     Тюмень             ultra  4028.687306
# ...        ...      ...  ...        ...               ...          ...
# 18063     1534  Альберт   25  Краснодар              free  3781.098080
# 18064     1534  Альберт   25  Краснодар              free  2840.423057
# 18065     1534  Альберт   25  Краснодар              free  3826.185507
# 18066     1534  Альберт   25  Краснодар              free  2902.308661
# 18067     1534  Альберт   25  Краснодар              free  2371.711192
#
#        duration       date  month_number  minute_price  start_ride_price  \
# ...

# %% [markdown]
# Сравним размеры датасетов до и после объединения. И проверим готовую таблицу на пропуски. Ориентироваться будем по датасету data_rdrs как имеющему большее количество строк.

# %%
display (data_rdrs.info())
display (merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       18068 non-null  int64
#  1   distance      18068 non-null  float64
#  2   duration      18068 non-null  float64
#  3   date          18068 non-null  datetime64[ns]
#  4   month_number  18068 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2)
# memory usage: 705.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18068 entries, 0 to 18067
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            18068 non-null  int64
#  1   name               18068 non-null  object
#  2   age                18068 non-null  int64
#  3   city               18068 non-null  object
#  4   subscription_type  18068 non-null  object
# ...

# %% [markdown]
# Проверим объединенную таблицу на пропуски.

# %%
merged_df.isna().sum()
# Out:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# distance             0
# duration             0
# date                 0
# month_number         0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %% [markdown]
# Объединение прошло корректно.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Объединение прошло корректно.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Замечания:
#
# * Для начала следует посмотреть исходную размерность датасетов
#
# * После объединения размерность таблицы, к которой присоединяем должна совпадать с исходной.
#
# * Отсутствует проверка на пропуски в объединенном датасете.
#
# Дополни, пожалуйста.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Добавил проверку таблицы. Сравнил размеры таблицы до и после объединения и проверил на пропуски.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Супер
# </div>

# %% [markdown]
# **4.2** Создадим ещё два датафрейма. Один с пользователями без подписки и второй с пользователями с подпиской.

# %%
free_subscr = merged_df.query("`subscription_type` == 'free'")
free_subscr
# Out:
#        user_id     name  age       city subscription_type     distance  \
# 6500       700    Айдар   22       Омск              free  2515.690719
# 6501       700    Айдар   22       Омск              free   846.932642
# 6502       700    Айдар   22       Омск              free  4004.434142
# 6503       700    Айдар   22       Омск              free  1205.911290
# 6504       700    Айдар   22       Омск              free  3047.379435
# ...        ...      ...  ...        ...               ...          ...
# 18063     1534  Альберт   25  Краснодар              free  3781.098080
# 18064     1534  Альберт   25  Краснодар              free  2840.423057
# 18065     1534  Альберт   25  Краснодар              free  3826.185507
# 18066     1534  Альберт   25  Краснодар              free  2902.308661
# 18067     1534  Альберт   25  Краснодар              free  2371.711192
#
#        duration       date  month_number  minute_price  start_ride_price  \
# ...

# %%
ultra_subscr = merged_df.query("`subscription_type` == 'ultra'")
free_subscr
# Out:
#        user_id     name  age       city subscription_type     distance  \
# 6500       700    Айдар   22       Омск              free  2515.690719
# 6501       700    Айдар   22       Омск              free   846.932642
# 6502       700    Айдар   22       Омск              free  4004.434142
# 6503       700    Айдар   22       Омск              free  1205.911290
# 6504       700    Айдар   22       Омск              free  3047.379435
# ...        ...      ...  ...        ...               ...          ...
# 18063     1534  Альберт   25  Краснодар              free  3781.098080
# 18064     1534  Альберт   25  Краснодар              free  2840.423057
# 18065     1534  Альберт   25  Краснодар              free  3826.185507
# 18066     1534  Альберт   25  Краснодар              free  2902.308661
# 18067     1534  Альберт   25  Краснодар              free  2371.711192
#
#        duration       date  month_number  minute_price  start_ride_price  \
# ...

# %%
free_subscr.distance.plot(kind='hist', y='Количество поездок',title='Распределение расстояния среди пользователей без подписки', xlabel=('Расстояние, м'), ylabel=('Количество поездок'), bins = 30, figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Распределение расстояния среди пользователей без подписки'}, ylabel='Frequency'>

# %%
free_subscr.duration.plot(kind='hist', y='Количество поездок',title='Распределение времени среди пользователей без подписки', xlabel=('Время, мин.'), ylabel=('Количество поездок'), bins = 30, figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Распределение времени среди пользователей без подписки'}, ylabel='Frequency'>

# %%
ultra_subscr.distance.plot(kind='hist', y='Количество поездок',title='Распределение расстояния среди пользователей с подпиской', xlabel=('Расстояние, м'), ylabel=('Количество поездок'), bins = 30, figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Распределение расстояния среди пользователей с подпиской'}, ylabel='Frequency'>

# %%
ultra_subscr.duration.plot(kind='hist', y='Количество поездок',title='Распределение времени среди пользователей с подпиской', xlabel=('Время, мин.'), ylabel=('Количество поездок'), bins = 30, figsize=(14,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'Распределение времени среди пользователей с подпиской'}, ylabel='Frequency'>

# %% [markdown]
# Выводы: После построения графиков распределения расстояний и времени среди пользователей с подпиской и без неё, можно уже сделать некоторые выводы.
# Так пользователи без подписки в среднем проезжают от 2 до 4.5 километра за поездку и тратят на это от 10 до 25 минут.
# Протяженность поездок отличается у пользователей с подпиской.
# Пользователи с подпиской проезжают от 2.5 до 4 км в среднем и затрачивают немного меньше времени чем пользователи без подписки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы верны, визуализация корректная. Здорово, что есть сравнения профилей пользователей двух категорий.
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 📝
# Также можно совместить графики распределений для более наглядного сравнения.
# </div>

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# **5.1** Создадим датафрейм с агрегированными данными о поездках пользователей сервиса. Найдем суммарное расстояние, время и количество поездок каждым пользователейм за месяц.

# %%
usrs_pivot = pd.pivot_table(merged_df, index=['user_id','month_number'], values = ['distance', 'duration', 'name', 'subscription_type'], aggfunc = {'distance': sum,'duration' : sum, 'name' : len, 'subscription_type' : min})
usrs_pivot.rename(columns = {'name' : 'trips'}, inplace = True)
usrs_pivot.sort_values(by='month_number').head(10)
# Out:
#                          distance  duration  trips subscription_type
# user_id month_number
# 1       1             7027.511294      42.0      2             ultra
# 686     1             9891.825690      53.0      3             ultra
# 685     1             4837.670420      47.0      2             ultra
# 682     1             2929.820795      25.0      1             ultra
# 680     1             3316.977004      18.0      1             ultra
# 679     1             6407.866143      38.0      2             ultra
# 675     1             3907.983157      21.0      1             ultra
# 674     1             2952.626152      11.0      1             ultra
# 673     1             3371.773487      24.0      1             ultra
# 671     1             3649.397977      12.0      1             ultra

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Используя этот код, мы первично группируем данные по `month_number`, что может привести к неверным результатам, поскольку не учитывается агрегация для каждого пользователя внутри каждого месяца. Необходимо сначала группировать данные по `user_id`, а затем по `month_number`, чтобы правильно агрегировать информацию.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Исправил последовательность аггрегации. Запомню на будущее.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# **5.2** Добавим в датафрейм столбец в выручкой которую принес каждый пользователь.

# %%
def month_revnue(i):
    if i['subscription_type'] == 'ultra':
        return 6*i['duration']+199
    elif i['subscription_type'] == 'free':
        return 50*i['trips']+8*i['duration']

# %%
usrs_pivot['month_revenue'] = usrs_pivot.apply(month_revnue, axis=1)

# %%
usrs_pivot.head(10)
# Out:
#                           distance  duration  trips subscription_type  \
# user_id month_number
# 1       1              7027.511294      42.0      2             ultra
#         4               754.159807       7.0      1             ultra
#         8              6723.470560      46.0      2             ultra
#         10             5809.911100      32.0      2             ultra
#         11             7003.499363      56.0      3             ultra
#         12             6751.629942      28.0      2             ultra
# 2       3             10187.723006      63.0      3             ultra
#         4              6164.381824      40.0      2             ultra
#         6              3255.338202      14.0      1             ultra
#         7              6780.722964      48.0      2             ultra
#
#                       month_revenue
# user_id month_number
# 1       1                     451.0
#         4                     241.0
#         8                     475.0
# ...

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# **6.1** Проверим гипотезу что пользователи с подпиской тратят больше времени на поездки.

# %% [markdown]
# Н_0 время использования сервиса пользователями с подпиской = времени использования сервиса пользователей без подписки;
# Н_1 время использования сервиса пользователями с подпиской > времени использования сервиса пользователей без подписки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Гипотезы сформулированы верно
# </div>

# %% [markdown]
# **Проверим нулевую гипотезу**

# %%
hyp_time_test =  st.ttest_ind(ultra_subscr['duration'], free_subscr['duration'], alternative = 'greater')

alpha = 0.05 

print(hyp_time_test.pvalue)

if hyp_time_test.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 2.4959453720736625e-34
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод**
# Отвергаем гипотезу о том, что время поездки пользователей с подпиской равно времени пользователей без подписки.

# %% [markdown]
# **6.2**  Проверим гипотезу, что пользователи с подпиской за одну поездку проезжают не больше 3130м.

# %% [markdown]
# Н_0 - расстояние за одну поездку пользователями с подпиской = 3130м.;
# Н_1 - расстояние за одну поездку пользователями с подпиской > 3130м.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Поскольку оптимальное расстояние по износу составляет 3130 м, значит большее расстояние приводит к повышенному износу самоката. Следовательно, имеет смысл сформулировать альтернативную гипотезу "Подписчики в среднем проезжают расстояние больше оптимального" и соответственно в статистическом тесте использовать параметр `alternative = 'greater'`
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Исправил гипотезу на правостороннюю.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %%
interested_value = 3130.0

hyp_dist_test =  st.ttest_1samp(ultra_subscr['distance'], interested_value, alternative = 'greater', )

alpha = 0.05 

print(hyp_dist_test.pvalue)

if hyp_dist_test.pvalue > alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 0.9195368847849785
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод**
# Отвергаем гипотезу о том, что пользователи с подпиской проезжают за одну поездку не больше 3130м.

# %% [markdown]
# **6.3** Проверим гипотезу что помесячная выручка пользователей сервиса с подпиской больше чем выручка от пользователей без подписки.

# %% [markdown]
# Н_0 - помесячная выручка от пользователей с подпиской = выручке пользователей без подписки;
# Н_1 - расстояние за одну поездку пользователями с подпиской > выручке пользователей без подписки.

# %%
usrs_pivot
# Out:
#                           distance  duration  trips subscription_type  \
# user_id month_number
# 1       1              7027.511294      42.0      2             ultra
#         4               754.159807       7.0      1             ultra
#         8              6723.470560      46.0      2             ultra
#         10             5809.911100      32.0      2             ultra
#         11             7003.499363      56.0      3             ultra
# ...                            ...       ...    ...               ...
# 1534    6              3409.468534      26.0      2              free
#         8              7622.453034      48.0      2              free
#         9              4928.173852      23.0      1              free
#         11            13350.015305      78.0      4              free
#         12             2371.711192      16.0      1              free
#
#                       month_revenue
# user_id month_number
# 1       1                     451.0
# ...

# %%
subscr_per_month = usrs_pivot.query('subscription_type == "ultra"')['month_revenue']
nosubscr_per_month = usrs_pivot.query('subscription_type == "free"')['month_revenue'] 


hyp_revenue_test = st.ttest_ind(subscr_per_month, nosubscr_per_month, alternative = 'greater')


alpha = 0.05 

print(hyp_revenue_test.pvalue)

if hyp_revenue_test.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не удалось отвергнуть нулевую гипотезу')
# Out:
# 1.8850394384715216e-31
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод**
# Мы не можем утверждать, что выручка от пользователей с подпиской превышает выручку от пользователей без подписки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Здесь корректно
# </div>

# %% [markdown]
# **6.4** Рассмотрим ситуацию: техническая команда сервиса обновила сервера, с которыми взаимодействует мобильное приложение. Результатом должно быть снижение обращений пользователей в техподдержку.

# %% [markdown]
# Проверим гипотезу о равенстве количества обращений пользователей в техподдержку после обновления мобильного приложения.
# **Н_0** количество обращений в техподдержку после обновления приложения = количеству обращений в техподдержку до обновления приложения;
# **Н_1** количество обращений в техподдержку после обновления приложения <= количеству обращений в техподдержку до обновления приложения.

# %% [markdown]
# Для проверки гипотезы используем метод scipy.stats.ttest_rel()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Метод выбран правильно.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# ✍
# Мы используем односторонний тест, потому что нас интересует только одно направление изменения (уменьшилось ли количество обращений или нет). Нам не интересно, увеличилось ли количество обращений после обновления, так как это не соответствует нашей изначальной гипотезе о положительном эффекте обновления серверов.
#
# Основная (нулевая) гипотеза в этом случае может утверждать, что различия между количеством обращений до и после обновления отсутствуют или что количество обращений после обновления больше или равно, чем до.
#
# Альтернативная гипотеза будет утверждать, что количество обращений после обновления меньше, чем до обновления.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Все верно. Цель обновления сервиса это снижение обращений пользователей в техподдержку. Исправил гипотезу на левостороннюю.
#
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
#
# </div>

# %% [markdown]
# #### Общий вывод

# %% [markdown]
# Нам было предоставлено 3 датасета с информацией о пользователях сервиса аренды самокатов GoFast. Пропусков в предоставленных датасетах небыло, а дубликатов было менее 1 процента, поэтому они были удалены.
# На этапе исследовательского анализа данных была проведена оценка сервиса по разным критериям.
# Выяснилось что сервис наиболее популярен в Пятигорске, а наименее популярен в Москве.
# Чуть больше половины пользователей сервиса не хотят оформлять подписку.
# Наибольшую популярность сервис имеет среди 25 летних.
# Пользователи без подписки в среднем проезжают от 2 до 4.5 километра за поездку и тратят на это от 10 до 25 минут.
# Протяженность поездок немного отличается у пользователей с подпиской. Пользователи с подпиской проезжают от 2.5 до 4 км в среднем и затрачивают немного меньше времени чем пользователи без подписки.
# В результате проверки гипотез были сделаны следующие выводы.
#
# Пользователи сервиса с подпиской не приносят компании большего дохода чем пользователи без подписки.
# Пользователи у которых есть подписка не тратят на сервис больше времени чем люди без подписки.
# Гипотеза о том, что пользователи с подпиской проезжают за одну поездку не больше 3130м была отвергнута.
# Мы не можем утверждать, что выручка от пользователей с подпиской превышает выручку от пользователей без подписки.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Владимир, замечательная работа, ты мыслишь нестандартно, это отличный навык, который у тебя уже есть, ты последователен и вдумчив. Твою работу очень интересно читать и проверять.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Владимир, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта 🥳 🎉
#
# И желаю успехов в новых работах 😊
